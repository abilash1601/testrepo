# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales_df=pd.read_csv('AusApparalSales.csv')

# %%
sales_df
# Out:
#              Date        Time State     Group  Unit  Sales
# 0      1-Oct-2020     Morning    WA      Kids     8  20000
# 1      1-Oct-2020     Morning    WA       Men     8  20000
# 2      1-Oct-2020     Morning    WA     Women     4  10000
# 3      1-Oct-2020     Morning    WA   Seniors    15  37500
# 4      1-Oct-2020   Afternoon    WA      Kids     3   7500
# ...           ...         ...   ...       ...   ...    ...
# 7555  30-Dec-2020   Afternoon   TAS   Seniors    14  35000
# 7556  30-Dec-2020     Evening   TAS      Kids    15  37500
# 7557  30-Dec-2020     Evening   TAS       Men    15  37500
# 7558  30-Dec-2020     Evening   TAS     Women    11  27500
# 7559  30-Dec-2020     Evening   TAS   Seniors    13  32500
#
# [7560 rows x 6 columns]

# %%
sales_df.shape
# Out:
# (7560, 6)

# %%
sales_df.isna().sum()
# Out:
# Date     0
# Time     0
# State    0
# Group    0
# Unit     0
# Sales    0
# dtype: int64

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7560 entries, 0 to 7559
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    7560 non-null   object
#  1   Time    7560 non-null   object
#  2   State   7560 non-null   object
#  3   Group   7560 non-null   object
#  4   Unit    7560 non-null   int64
#  5   Sales   7560 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 354.5+ KB

# %%
## when we have missing values for abt 10% then we can drop them
#industry standards say we can drop values upto 30 % because we'll still have 70% data.
# when missing values is between 20% and 70% we can impute values  
#Here in this data there is no missing values.

# %%
##normalization

# %%
sales_numeric=sales_df[['Unit','Sales']]

# %%
sales_numeric
# Out:
#       Unit  Sales
# 0        8  20000
# 1        8  20000
# 2        4  10000
# 3       15  37500
# 4        3   7500
# ...    ...    ...
# 7555    14  35000
# 7556    15  37500
# 7557    15  37500
# 7558    11  27500
# 7559    13  32500
#
# [7560 rows x 2 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
normalize=MinMaxScaler()

# %%
normalizes_data=normalize.fit_transform(sales_numeric)
print(normalizes_data)
# Out:
# [[0.0952381  0.0952381 ]
#  [0.0952381  0.0952381 ]
#  [0.03174603 0.03174603]
#  ...
#  [0.20634921 0.20634921]
#  [0.14285714 0.14285714]
#  [0.17460317 0.17460317]]

# %%
#grouby()

# %%
#get summary of basic statistics

# %%
sales_df.describe()
# Out:
#               Unit          Sales
# count  7560.000000    7560.000000
# mean     18.005423   45013.558201
# std      12.901403   32253.506944
# min       2.000000    5000.000000
# 25%       8.000000   20000.000000
# 50%      14.000000   35000.000000
# 75%      26.000000   65000.000000
# max      65.000000  162500.000000

# %%
#### highest and lowest sales :
highest_sales_group=sales_df.groupby(['Group']).sum('Sales').idxmax()
lowest_sales_group=sales_df.groupby(['Group']).sum('Sales').idxmin()
print(highest_sales_group)
print(lowest_sales_group)
# Out:
# Unit      Men
# Sales     Men
# dtype: object
# Unit      Seniors
# Sales     Seniors
# dtype: object

# %%
highest_sales_state=sales_df.groupby(['State']).sum('Sales').idxmax()
lowest_sales_state=sales_df.groupby(['State']).sum('Sales').idxmin()
highest_sales_state
# Out:
# Unit      VIC
# Sales     VIC
# dtype: object

# %%
###2D
print(sales_df.Date.unique())
# Out:
# ['1-Oct-2020' '2-Oct-2020' '3-Oct-2020' '4-Oct-2020' '5-Oct-2020'
#  '6-Oct-2020' '7-Oct-2020' '8-Oct-2020' '9-Oct-2020' '10-Oct-2020'
#  '11-Oct-2020' '12-Oct-2020' '13-Oct-2020' '14-Oct-2020' '15-Oct-2020'
#  '16-Oct-2020' '17-Oct-2020' '18-Oct-2020' '19-Oct-2020' '20-Oct-2020'
#  '21-Oct-2020' '22-Oct-2020' '23-Oct-2020' '24-Oct-2020' '25-Oct-2020'
#  '26-Oct-2020' '27-Oct-2020' '28-Oct-2020' '29-Oct-2020' '30-Oct-2020'
#  '1-Nov-2020' '2-Nov-2020' '3-Nov-2020' '4-Nov-2020' '5-Nov-2020'
#  '6-Nov-2020' '7-Nov-2020' '8-Nov-2020' '9-Nov-2020' '10-Nov-2020'
#  '11-Nov-2020' '12-Nov-2020' '13-Nov-2020' '14-Nov-2020' '15-Nov-2020'
#  '16-Nov-2020' '17-Nov-2020' '18-Nov-2020' '19-Nov-2020' '20-Nov-2020'
#  '21-Nov-2020' '22-Nov-2020' '23-Nov-2020' '24-Nov-2020' '25-Nov-2020'
#  '26-Nov-2020' '27-Nov-2020' '28-Nov-2020' '29-Nov-2020' '30-Nov-2020'
#  '1-Dec-2020' '2-Dec-2020' '3-Dec-2020' '4-Dec-2020' '5-Dec-2020'
#  '6-Dec-2020' '7-Dec-2020' '8-Dec-2020' '9-Dec-2020' '10-Dec-2020'
# ...

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7560 entries, 0 to 7559
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    7560 non-null   object
#  1   Time    7560 non-null   object
#  2   State   7560 non-null   object
#  3   Group   7560 non-null   object
#  4   Unit    7560 non-null   int64
#  5   Sales   7560 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 354.5+ KB

# %%
sales_df['Date']=pd.to_datetime(sales_df['Date'])

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7560 entries, 0 to 7559
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    7560 non-null   datetime64[ns]
#  1   Time    7560 non-null   object
#  2   State   7560 non-null   object
#  3   Group   7560 non-null   object
#  4   Unit    7560 non-null   int64
#  5   Sales   7560 non-null   int64
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 354.5+ KB

# %%
df_unit_sales=sales_df.groupby('Date',axis='index').sum()
# Out:
# C:\Users\Abilash\AppData\Local\Temp\ipykernel_12600\3113614559.py:1: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   df_unit_sales=sales_df.groupby('Date',axis='index').sum()

# %%
df_unit_sales
# Out:
#                                                          Time  \
# Date
# 2020-10-01   Morning Morning Morning Morning Afternoon Aft...
# 2020-10-02   Morning Morning Morning Morning Afternoon Aft...
# 2020-10-03   Morning Morning Morning Morning Afternoon Aft...
# 2020-10-04   Morning Morning Morning Morning Afternoon Aft...
# 2020-10-05   Morning Morning Morning Morning Afternoon Aft...
# ...                                                       ...
# 2020-12-26   Morning Morning Morning Morning Afternoon Aft...
# 2020-12-27   Morning Morning Morning Morning Afternoon Aft...
# 2020-12-28   Morning Morning Morning Morning Afternoon Aft...
# 2020-12-29   Morning Morning Morning Morning Afternoon Aft...
# 2020-12-30   Morning Morning Morning Morning Afternoon Aft...
#
#                                                         State  \
# Date
# 2020-10-01   WA WA WA WA WA WA WA WA WA WA WA WA NT NT NT ...
# 2020-10-02   WA WA WA WA WA WA WA WA WA WA WA WA NT NT NT ...
# ...

# %%
df_oct=df_unit_sales.loc['2020-10-01':'2020-10-30']

# %%
df_oct
# Out:
#                                                          Time  \
# Date
# 2020-10-01   Morning Morning Morning Morning Afternoon Aft...
# 2020-10-02   Morning Morning Morning Morning Afternoon Aft...
# 2020-10-03   Morning Morning Morning Morning Afternoon Aft...
# 2020-10-04   Morning Morning Morning Morning Afternoon Aft...
# 2020-10-05   Morning Morning Morning Morning Afternoon Aft...
# 2020-10-06   Morning Morning Morning Morning Afternoon Aft...
# 2020-10-07   Morning Morning Morning Morning Afternoon Aft...
# 2020-10-08   Morning Morning Morning Morning Afternoon Aft...
# 2020-10-09   Morning Morning Morning Morning Afternoon Aft...
# 2020-10-10   Morning Morning Morning Morning Afternoon Aft...
# 2020-10-11   Morning Morning Morning Morning Afternoon Aft...
# 2020-10-12   Morning Morning Morning Morning Afternoon Aft...
# 2020-10-13   Morning Morning Morning Morning Afternoon Aft...
# 2020-10-14   Morning Morning Morning Morning Afternoon Aft...
# ...

# %%
df_oct.shape
# Out:
# (30, 5)

# %%
df_nov=df_unit_sales.loc['2020-11-01':'2020-11-30']
df_nov
# Out:
#                                                          Time  \
# Date
# 2020-11-01   Morning Morning Morning Morning Afternoon Aft...
# 2020-11-02   Morning Morning Morning Morning Afternoon Aft...
# 2020-11-03   Morning Morning Morning Morning Afternoon Aft...
# 2020-11-04   Morning Morning Morning Morning Afternoon Aft...
# 2020-11-05   Morning Morning Morning Morning Afternoon Aft...
# 2020-11-06   Morning Morning Morning Morning Afternoon Aft...
# 2020-11-07   Morning Morning Morning Morning Afternoon Aft...
# 2020-11-08   Morning Morning Morning Morning Afternoon Aft...
# 2020-11-09   Morning Morning Morning Morning Afternoon Aft...
# 2020-11-10   Morning Morning Morning Morning Afternoon Aft...
# 2020-11-11   Morning Morning Morning Morning Afternoon Aft...
# 2020-11-12   Morning Morning Morning Morning Afternoon Aft...
# 2020-11-13   Morning Morning Morning Morning Afternoon Aft...
# 2020-11-14   Morning Morning Morning Morning Afternoon Aft...
# ...

# %%
df_dec=df_unit_sales.loc['2020-12-01':'2020-12-30']
df_dec.shape
# Out:
# (30, 5)

# %%
sns.set(rc={'figure.figsize':(18,8)})

fig,axes=plt.subplots(1,3)

bp_oct=sns.boxplot(x='Sales',data=df_oct,ax=axes[0],color='r')
bp_nov=sns.boxplot(x='Sales',data=df_nov,ax=axes[1],color='b')
bp_dec=sns.boxplot(x='Sales',data=df_dec,ax=axes[2],color='g')

bp_oct.set(title='October Sales')
bp_nov.set(title='November Sales')
bp_dec.set(title='December Sales')

plt.show()

# %% [markdown]
# ## From the above figure we can see that the sales during the month of october has been consistent and didnt have any outliers but sales during november and december has outliers which shows drastic drop and spike in sales.
#
# ### November sees a dip in the beginning of the month and by the end of the month there is a spike .December has recorded the highest sales .

# %%
sns.set(rc={'figure.figsize':(18,8)})
sns.lineplot(x='Date',y='Sales',data=sales_df)
plt.show()

# %% [markdown]
# ## The line plot suugests the same as the boxplot. Oct has large and consistent sales throughout the month.November sees a dip initially and towards the end , there is a spike. December records the highest sales and has a spike beginning of the month.

# %%
weekly_data=sales_df.resample('W',on='Date')['Sales'].sum()
weekly_data
# Out:
# Date
# 2020-10-04    15045000
# 2020-10-11    27002500
# 2020-10-18    26640000
# 2020-10-25    26815000
# 2020-11-01    21807500
# 2020-11-08    20865000
# 2020-11-15    21172500
# 2020-11-22    21112500
# 2020-11-29    21477500
# 2020-12-06    29622500
# 2020-12-13    31525000
# 2020-12-20    31655000
# 2020-12-27    31770000
# 2021-01-03    13792500
# Freq: W-SUN, Name: Sales, dtype: int64

# %%
sales_df.resample('W',on='Date')['Sales'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
print(weekly_data.idxmax())
print(weekly_data.max())
print(weekly_data.idxmin())
print(weekly_data.min())
# Out:
# 2020-12-27 00:00:00
# 31770000
# 2021-01-03 00:00:00
# 13792500

# %%
monthly_data=sales_df.resample('ME',on='Date')['Sales'].sum()   ## for monthly it is 'ME'
monthly_data
# Out:
# Date
# 2020-10-31    114290000
# 2020-11-30     90682500
# 2020-12-31    135330000
# Freq: ME, Name: Sales, dtype: int64

# %%
sales_df.resample('ME',on='Date')['Sales'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
print(monthly_data.idxmax())
print(monthly_data.max())
print(monthly_data.idxmin())
print(monthly_data.min())
# Out:
# 2020-12-31 00:00:00
# 135330000
# 2020-11-30 00:00:00
# 90682500

# %%
quarterly_data=sales_df.resample('QE',on='Date')['Sales'].sum()
quarterly_data
# Out:
# Date
# 2020-12-31    340302500
# Freq: QE-DEC, Name: Sales, dtype: int64

# %%
sales_df.resample('QE',on='Date')['Sales'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %%
##3A

# %%
plt.figure(figsize=(8,6))
sns.barplot(x=sales_df['State'],y=sales_df['Sales'],data=sales_df)
plt.show()

# %%
sns.barplot(x=sales_df['State'],y=sales_df['Sales'],hue='Group',data=sales_df)
plt.show()

# %% [markdown]
# ## As the graph suggests , we can see that VIC has recorded the most no.of sales in the country and WA has done the least sales in the country.
#
# ### The contributors to the sales in VIC are Women, men, kids and seniors respectively.
# ### Whereas in the WA the contibutors to sales are Men, kids, seniors and women respectively.
#
# ## Women have been the highest contributors in the highest state as well as the lowest in the lowest state.

# %%
sns.barplot(x=sales_df['Group'],y=sales_df['Sales'],data=sales_df)
plt.show()

# %%
sns.barplot(x=sales_df['Time'],y=sales_df['Sales'])
plt.show()

# %% [markdown]
# ## We can see that most of the sales have been recorded in the first half of the day ie. in the Morning and in the Afternoon. It would be in the best interest of the company if we adapt more intensive campaigns and ads during the day to attract many consumers. Additional offers could also be provided for day customers.

# %%
## Why are we using seaborn package over matplotlib?

# %% [markdown]
# ### Seaborn is often preferred over Matplotlib for data visualization because it provides a higher-level interface for creating visually appealing and informative statistical graphics. It also has better aesthetics and simpler syntax. Since we are dealing with multiple plots and figures in this data , its better that we use the seaborn package.

# %%
##4C

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x=sales_df['Unit'])
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x=sales_df['Sales'])
plt.title('boxplot for sales')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

sns.distplot(x=sales_df['Sales'])
plt.show()

# %% [markdown]
# ## This data has a postive relationship . It is positively skewed.

# %%
sns.histplot(x=sales_df['Unit'],kde=True)
plt.show()

# %% [markdown]
# ### As already mentioned positively skewed data

# %%
#### pairplots will help us with univariate and bivariate analysis:
sns.pairplot(data=sales_df)
plt.show()

# %% [markdown]
# ## Shows strong positive relationship between units and sales , it has a one to one relationship. When sales increases the units also increases.

# %%
sales_df.corr(numeric_only=True)
# Out:
#        Unit  Sales
# Unit    1.0    1.0
# Sales   1.0    1.0
